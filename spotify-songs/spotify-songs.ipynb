# %%
import pandas as pd
import numpy as np
# %matplotlib inline 
import seaborn as sns
sns.set(style='darkgrid')

# %%
df = pd.read_csv('datasets/top50.csv',encoding='latin')
df.to_csv('datasets/top50ok.csv',encoding='utf-8')

# %%
df = pd.read_csv('datasets/top50ok.csv',index_col=0)
df.head()
# Out:
#    Unnamed: 0.1                       Track.Name    Artist.Name  \
# 0             1                         Señorita   Shawn Mendes
# 1             2                            China       Anuel AA
# 2             3    boyfriend (with Social House)  Ariana Grande
# 3             4  Beautiful People (feat. Khalid)     Ed Sheeran
# 4             5      Goodbyes (Feat. Young Thug)    Post Malone
#
#             Genre  Beats.Per.Minute  Energy  Danceability  Loudness..dB..  \
# 0    canadian pop               117      55            76              -6
# 1  reggaeton flow               105      81            79              -4
# 2       dance pop               190      80            40              -4
# 3             pop                93      65            64              -8
# 4         dfw rap               150      65            58              -4
#
#    Liveness  Valence.  Length.  Acousticness..  Speechiness.  Popularity
# 0         8        75      191               4             3          79
# 1         8        61      302               8             9          92
# 2        16        70      186              12            46          85
# 3         8        55      198              12            19          86
# 4        11        18      175              45             7          94

# %%
df_count_genre = df.groupby('Genre')[['Energy']].count().rename(columns={'Energy':'Count'}).reset_index()

# %%
sns.barplot(x='Count', y='Genre', data=df_count_genre,ci=68)

# %%
df.corr()
# Out:
#                   Unnamed: 0.1  Beats.Per.Minute    Energy  Danceability  \
# Unnamed: 0.1          1.000000         -0.259193  0.102649      0.122691
# Beats.Per.Minute     -0.259193          1.000000  0.043756     -0.094183
# Energy                0.102649          0.043756  1.000000      0.018254
# Danceability          0.122691         -0.094183  0.018254      1.000000
# Loudness..dB..        0.011914          0.017016  0.670794      0.016255
# Liveness              0.270659         -0.167286  0.162768     -0.149636
# Valence.              0.137329         -0.011586  0.438820      0.172829
# Length.              -0.065844         -0.139288  0.224677     -0.000185
# Acousticness..       -0.015993         -0.031450 -0.339892     -0.098165
# Speechiness.         -0.257506          0.557052 -0.089860     -0.103472
# Popularity           -0.160680          0.196097 -0.080295     -0.071413
#
#                   Loudness..dB..  Liveness  Valence.   Length.  \
# Unnamed: 0.1            0.011914  0.270659  0.137329 -0.065844
# Beats.Per.Minute        0.017016 -0.167286 -0.011586 -0.139288
# Energy                  0.670794  0.162768  0.438820  0.224677
# Danceability            0.016255 -0.149636  0.172829 -0.000185
# Loudness..dB..          1.000000  0.258652  0.237614  0.219219
# Liveness                0.258652  1.000000  0.016123  0.131782
# Valence.                0.237614  0.016123  1.000000 -0.017782
# Length.                 0.219219  0.131782 -0.017782  1.000000
# Acousticness..         -0.138300  0.021328 -0.052323 -0.076293
# Speechiness.           -0.272213 -0.125286 -0.053242  0.046755
# Popularity             -0.043085  0.092564 -0.317752 -0.087639
#
#                   Acousticness..  Speechiness.  Popularity
# Unnamed: 0.1           -0.015993     -0.257506   -0.160680
# Beats.Per.Minute       -0.031450      0.557052    0.196097
# Energy                 -0.339892     -0.089860   -0.080295
# Danceability           -0.098165     -0.103472   -0.071413
# Loudness..dB..         -0.138300     -0.272213   -0.043085
# Liveness                0.021328     -0.125286    0.092564
# Valence.               -0.052323     -0.053242   -0.317752
# Length.                -0.076293      0.046755   -0.087639
# Acousticness..          1.000000      0.008293   -0.034684
# Speechiness.            0.008293      1.000000    0.238553
# Popularity             -0.034684      0.238553    1.000000

# %%
df.cov()
# Out:
#                   Unnamed: 0.1  Beats.Per.Minute      Energy  Danceability  \
# Unnamed: 0.1        212.500000       -116.744898   21.295918     21.336735
# Beats.Per.Minute   -116.744898        954.710612   19.241224    -34.717143
# Energy               21.295918         19.241224  202.547347      3.099184
# Danceability         21.336735        -34.717143    3.099184    142.322041
# Loudness..dB..        0.357143          1.081224   19.632245      0.398776
# Liveness             43.867347        -57.468980   25.755510    -19.847755
# Valence.             44.714286         -7.995918  139.493878     46.053061
# Length.             -37.571429       -168.466939  125.165714     -0.086531
# Acousticness..       -4.428571        -18.458776  -91.887347    -22.245714
# Speechiness.        -41.897959        192.113469  -14.274286    -13.777959
# Popularity          -10.520408         27.214286   -5.132653     -3.826531
#
#                   Loudness..dB..    Liveness    Valence.      Length.  \
# Unnamed: 0.1            0.357143   43.867347   44.714286   -37.571429
# Beats.Per.Minute        1.081224  -57.468980   -7.995918  -168.466939
# Energy                 19.632245   25.755510  139.493878   125.165714
# Danceability            0.398776  -19.847755   46.053061    -0.086531
# Loudness..dB..          4.228980    5.913878   10.914286    17.646531
# Liveness                5.913878  123.616735    4.004082    57.353469
# Valence.               10.914286    4.004082  498.897959   -15.546939
# Length.                17.646531   57.353469  -15.546939  1532.243265
# Acousticness..         -5.402449    4.504490  -22.200000   -56.728163
# Speechiness.           -6.248163  -15.547755  -13.273469    20.427755
# Popularity             -0.397959    4.622449  -31.877551   -15.408163
#
#                   Acousticness..  Speechiness.  Popularity
# Unnamed: 0.1           -4.428571    -41.897959  -10.520408
# Beats.Per.Minute      -18.458776    192.113469   27.214286
# Energy                -91.887347    -14.274286   -5.132653
# Danceability          -22.245714    -13.777959   -3.826531
# Loudness..dB..         -5.402449     -6.248163   -0.397959
# Liveness                4.504490    -15.547755    4.622449
# Valence.              -22.200000    -13.273469  -31.877551
# Length.               -56.728163     20.427755  -15.408163
# Acousticness..        360.831020      1.758367   -2.959184
# Speechiness.            1.758367    124.581224   11.959184
# Popularity             -2.959184     11.959184   20.173469

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Track.Name', 'Artist.Name', 'Genre',
#        'Beats.Per.Minute', 'Energy', 'Danceability', 'Loudness..dB..',
#        'Liveness', 'Valence.', 'Length.', 'Acousticness..', 'Speechiness.',
#        'Popularity'],
#       dtype='object')

# %%
sns.regplot(x='Speechiness.',y='Popularity',data=df)

# %%
correlation=df.corr(method='spearman')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.title('Correlation heatmap')
sns.heatmap(correlation,annot=True,vmin=-1,vmax=1,cmap="GnBu_r",center=1)

# %%
covariance = df.cov()

# %%
plt.figure(figsize=(10,10))
plt.title('covariance heatmap')
sns.heatmap(covariance,annot=True,vmin=-1,vmax=1,cmap="GnBu_r",center=1)

# %%
sns.regplot(x='Energy',y='Loudness..dB..',data=df,color='black')

# %%
fig=plt.subplots(figsize=(10,10))
plt.title('Dependence between energy and popularity')
sns.regplot(x='Energy', y='Popularity',
            ci=None, data=df)
sns.kdeplot(df.Energy,df.Popularity)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df)
plt.gcf().set_size_inches(30, 30)
plt.show()

# %%
import squarify as sq
sq.plot(sizes=df.Genre.value_counts(), label=df["Genre"].unique(), alpha=.8 )
