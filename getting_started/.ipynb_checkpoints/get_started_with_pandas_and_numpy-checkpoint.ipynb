# %%
import pandas as pd

# %%
import numpy as np

# %%
s = pd.Series([1,3,5,np.nan,6,8])

# %%
print(s)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101',periods=6)

# %%
print(dates)
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4),index=dates,columns=list('ABCD'))

# %%
print(df)
# Out:
#                    A         B         C         D
# 2013-01-01  0.204171 -0.702792  0.585163 -0.347610
# 2013-01-02 -0.437881 -0.646395 -0.390188 -0.340307
# 2013-01-03 -0.329085 -1.030596 -1.394362  1.978588
# 2013-01-04 -0.032635 -0.559504  0.144842  1.153715
# 2013-01-05  0.463446  1.221839 -0.489961  0.009261
# 2013-01-06  2.094690  1.804389 -2.092649  0.297863

# %%
df2 = pd.DataFrame({'A':1.,
                    'B':pd.Timestamp('20130102'),
                    'C':pd.Series(1,index=list(range(4)),dtype='float32'),
                    'D':np.array([3]*4,dtype='int32'),
                    'E':pd.Categorical(['test','train','test','train']),
                    'F':'foo'})

# %%
print(df2)
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df2.C
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# Name: C, dtype: float32

# %%
df2.E
# Out:
# 0     test
# 1    train
# 2     test
# 3    train
# Name: E, dtype: category
# Categories (2, object): [test, train]

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  0.204171 -0.702792  0.585163 -0.347610
# 2013-01-02 -0.437881 -0.646395 -0.390188 -0.340307
# 2013-01-03 -0.329085 -1.030596 -1.394362  1.978588
# 2013-01-04 -0.032635 -0.559504  0.144842  1.153715
# 2013-01-05  0.463446  1.221839 -0.489961  0.009261

# %%
df2.head()
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.tail(2)
# Out:
#      A          B    C  D      E    F
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df2.index
# Out:
# Int64Index([0, 1, 2, 3], dtype='int64')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df2.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[ 0.20417098, -0.70279198,  0.585163  , -0.34761043],
#        [-0.43788118, -0.64639525, -0.39018801, -0.34030677],
#        [-0.32908549, -1.03059562, -1.39436173,  1.97858813],
#        [-0.03263488, -0.55950438,  0.14484184,  1.15371451],
#        [ 0.46344625,  1.22183874, -0.48996137,  0.00926073],
#        [ 2.09469019,  1.80438934, -2.09264876,  0.29786305]])

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.327118  0.014490 -0.606193  0.458585
# std    0.927714  1.186117  0.987351  0.928388
# min   -0.437881 -1.030596 -2.092649 -0.347610
# 25%   -0.254973 -0.688693 -1.168262 -0.252915
# 50%    0.085768 -0.602950 -0.440075  0.153562
# 75%    0.398627  0.776503  0.011084  0.939752
# max    2.094690  1.804389  0.585163  1.978588

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.204171   -0.437881   -0.329085   -0.032635    0.463446    2.094690
# B   -0.702792   -0.646395   -1.030596   -0.559504    1.221839    1.804389
# C    0.585163   -0.390188   -1.394362    0.144842   -0.489961   -2.092649
# D   -0.347610   -0.340307    1.978588    1.153715    0.009261    0.297863

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01 -0.347610  0.585163 -0.702792  0.204171
# 2013-01-02 -0.340307 -0.390188 -0.646395 -0.437881
# 2013-01-03  1.978588 -1.394362 -1.030596 -0.329085
# 2013-01-04  1.153715  0.144842 -0.559504 -0.032635
# 2013-01-05  0.009261 -0.489961  1.221839  0.463446
# 2013-01-06  0.297863 -2.092649  1.804389  2.094690

# %%
df.sort_index(axis=1, ascending=True)
# Out:
#                    A         B         C         D
# 2013-01-01  0.204171 -0.702792  0.585163 -0.347610
# 2013-01-02 -0.437881 -0.646395 -0.390188 -0.340307
# 2013-01-03 -0.329085 -1.030596 -1.394362  1.978588
# 2013-01-04 -0.032635 -0.559504  0.144842  1.153715
# 2013-01-05  0.463446  1.221839 -0.489961  0.009261
# 2013-01-06  2.094690  1.804389 -2.092649  0.297863

# %%
df.sort_index(axis='index', ascending=True)
# Out:
#                    A         B         C         D
# 2013-01-01  0.204171 -0.702792  0.585163 -0.347610
# 2013-01-02 -0.437881 -0.646395 -0.390188 -0.340307
# 2013-01-03 -0.329085 -1.030596 -1.394362  1.978588
# 2013-01-04 -0.032635 -0.559504  0.144842  1.153715
# 2013-01-05  0.463446  1.221839 -0.489961  0.009261
# 2013-01-06  2.094690  1.804389 -2.092649  0.297863

# %%
df.sort_index(axis='columns', ascending=True)
# Out:
#                    A         B         C         D
# 2013-01-01  0.204171 -0.702792  0.585163 -0.347610
# 2013-01-02 -0.437881 -0.646395 -0.390188 -0.340307
# 2013-01-03 -0.329085 -1.030596 -1.394362  1.978588
# 2013-01-04 -0.032635 -0.559504  0.144842  1.153715
# 2013-01-05  0.463446  1.221839 -0.489961  0.009261
# 2013-01-06  2.094690  1.804389 -2.092649  0.297863

# %%
df.sort_index(axis='columns', ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01 -0.347610  0.585163 -0.702792  0.204171
# 2013-01-02 -0.340307 -0.390188 -0.646395 -0.437881
# 2013-01-03  1.978588 -1.394362 -1.030596 -0.329085
# 2013-01-04  1.153715  0.144842 -0.559504 -0.032635
# 2013-01-05  0.009261 -0.489961  1.221839  0.463446
# 2013-01-06  0.297863 -2.092649  1.804389  2.094690

# %%
df.sort_index(axis='index', ascending=True)
# Out:
#                    A         B         C         D
# 2013-01-01  0.204171 -0.702792  0.585163 -0.347610
# 2013-01-02 -0.437881 -0.646395 -0.390188 -0.340307
# 2013-01-03 -0.329085 -1.030596 -1.394362  1.978588
# 2013-01-04 -0.032635 -0.559504  0.144842  1.153715
# 2013-01-05  0.463446  1.221839 -0.489961  0.009261
# 2013-01-06  2.094690  1.804389 -2.092649  0.297863

# %%
df.sort_index(axis='index', ascending=False)
# Out:
#                    A         B         C         D
# 2013-01-06  2.094690  1.804389 -2.092649  0.297863
# 2013-01-05  0.463446  1.221839 -0.489961  0.009261
# 2013-01-04 -0.032635 -0.559504  0.144842  1.153715
# 2013-01-03 -0.329085 -1.030596 -1.394362  1.978588
# 2013-01-02 -0.437881 -0.646395 -0.390188 -0.340307
# 2013-01-01  0.204171 -0.702792  0.585163 -0.347610

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2013-01-03 -0.329085 -1.030596 -1.394362  1.978588
# 2013-01-01  0.204171 -0.702792  0.585163 -0.347610
# 2013-01-02 -0.437881 -0.646395 -0.390188 -0.340307
# 2013-01-04 -0.032635 -0.559504  0.144842  1.153715
# 2013-01-05  0.463446  1.221839 -0.489961  0.009261
# 2013-01-06  2.094690  1.804389 -2.092649  0.297863

# %%
df['A']
# Out:
# 2013-01-01    0.204171
# 2013-01-02   -0.437881
# 2013-01-03   -0.329085
# 2013-01-04   -0.032635
# 2013-01-05    0.463446
# 2013-01-06    2.094690
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  0.204171 -0.702792  0.585163 -0.347610
# 2013-01-02 -0.437881 -0.646395 -0.390188 -0.340307
# 2013-01-03 -0.329085 -1.030596 -1.394362  1.978588

# %%
df[0:4]
# Out:
#                    A         B         C         D
# 2013-01-01  0.204171 -0.702792  0.585163 -0.347610
# 2013-01-02 -0.437881 -0.646395 -0.390188 -0.340307
# 2013-01-03 -0.329085 -1.030596 -1.394362  1.978588
# 2013-01-04 -0.032635 -0.559504  0.144842  1.153715

# %%
df['20130102':'20130104']
# Out:
#                    A         B         C         D
# 2013-01-02 -0.437881 -0.646395 -0.390188 -0.340307
# 2013-01-03 -0.329085 -1.030596 -1.394362  1.978588
# 2013-01-04 -0.032635 -0.559504  0.144842  1.153715

# %%
df.loc[dates[0]]
# Out:
# A    0.204171
# B   -0.702792
# C    0.585163
# D   -0.347610
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:,['A','B']]
# Out:
#                    A         B
# 2013-01-01  0.204171 -0.702792
# 2013-01-02 -0.437881 -0.646395
# 2013-01-03 -0.329085 -1.030596
# 2013-01-04 -0.032635 -0.559504
# 2013-01-05  0.463446  1.221839
# 2013-01-06  2.094690  1.804389

# %%
df.loc['20130102':'20130103',['A','B']]
# Out:
#                    A         B
# 2013-01-02 -0.437881 -0.646395
# 2013-01-03 -0.329085 -1.030596

# %%
df.loc['20130102':'20130104',['C','A']]
# Out:
#                    C         A
# 2013-01-02 -0.390188 -0.437881
# 2013-01-03 -1.394362 -0.329085
# 2013-01-04  0.144842 -0.032635

# %%
serie1 = df.loc['20130102',['A','D']]
type(serie1)
# Out:
# pandas.core.series.Series

# %% [raw]
# print(serie1)

# %%
print(serie1)
# Out:
# A   -0.437881
# D   -0.340307
# Name: 2013-01-02 00:00:00, dtype: float64

# %%
serie1.mean()
# Out:
# -0.38909397678753443

# %%
df.iloc[3]
# Out:
# A   -0.032635
# B   -0.559504
# C    0.144842
# D    1.153715
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5,0:2]
# Out:
#                    A         B
# 2013-01-04 -0.032635 -0.559504
# 2013-01-05  0.463446  1.221839

# %%
df.iloc[3:5,1:2]
# Out:
#                    B
# 2013-01-04 -0.559504
# 2013-01-05  1.221839

# %%
df.iloc[3:5,0:1]
# Out:
#                    A
# 2013-01-04 -0.032635
# 2013-01-05  0.463446

# %%
df.iloc[[1,2,4],[0,2]]
# Out:
#                    A         C
# 2013-01-02 -0.437881 -0.390188
# 2013-01-03 -0.329085 -1.394362
# 2013-01-05  0.463446 -0.489961

# %%
df.iloc[:,0:3]
# Out:
#                    A         B         C
# 2013-01-01  0.204171 -0.702792  0.585163
# 2013-01-02 -0.437881 -0.646395 -0.390188
# 2013-01-03 -0.329085 -1.030596 -1.394362
# 2013-01-04 -0.032635 -0.559504  0.144842
# 2013-01-05  0.463446  1.221839 -0.489961
# 2013-01-06  2.094690  1.804389 -2.092649

# %%
df.iloc[1,1]
# Out:
# -0.6463952492244109

# %%
df.iat[1,1]
#this is faster than the approach above
# Out:
# -0.6463952492244109

# %%
df[df.A > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.204171 -0.702792  0.585163 -0.347610
# 2013-01-05  0.463446  1.221839 -0.489961  0.009261
# 2013-01-06  2.094690  1.804389 -2.092649  0.297863

# %%
df[df.B < df.C]
# Out:
#                    A         B         C         D
# 2013-01-01  0.204171 -0.702792  0.585163 -0.347610
# 2013-01-02 -0.437881 -0.646395 -0.390188 -0.340307
# 2013-01-04 -0.032635 -0.559504  0.144842  1.153715

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.204171       NaN  0.585163       NaN
# 2013-01-02       NaN       NaN       NaN       NaN
# 2013-01-03       NaN       NaN       NaN  1.978588
# 2013-01-04       NaN       NaN  0.144842  1.153715
# 2013-01-05  0.463446  1.221839       NaN  0.009261
# 2013-01-06  2.094690  1.804389       NaN  0.297863

# %%
df [df > df.C]
# Out:
#              A   B   C   D
# 2013-01-01 NaN NaN NaN NaN
# 2013-01-02 NaN NaN NaN NaN
# 2013-01-03 NaN NaN NaN NaN
# 2013-01-04 NaN NaN NaN NaN
# 2013-01-05 NaN NaN NaN NaN
# 2013-01-06 NaN NaN NaN NaN

# %%
df[df > df.A]
#it seems to doesnt work
# Out:
#              A   B   C   D
# 2013-01-01 NaN NaN NaN NaN
# 2013-01-02 NaN NaN NaN NaN
# 2013-01-03 NaN NaN NaN NaN
# 2013-01-04 NaN NaN NaN NaN
# 2013-01-05 NaN NaN NaN NaN
# 2013-01-06 NaN NaN NaN NaN

# %%
df2 = df.copy()

# %%
df2['E'] = ['one','one','two','three','four','three']

# %%
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.204171 -0.702792  0.585163 -0.347610    one
# 2013-01-02 -0.437881 -0.646395 -0.390188 -0.340307    one
# 2013-01-03 -0.329085 -1.030596 -1.394362  1.978588    two
# 2013-01-04 -0.032635 -0.559504  0.144842  1.153715  three
# 2013-01-05  0.463446  1.221839 -0.489961  0.009261   four
# 2013-01-06  2.094690  1.804389 -2.092649  0.297863  three

# %%
df2['E'].dtype
# Out:
# dtype('O')

# %%
df2[df2['E'].isin(['two','four'])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -0.329085 -1.030596 -1.394362  1.978588   two
# 2013-01-05  0.463446  1.221839 -0.489961  0.009261  four

# %%
s1 = pd.Series([1,2,3,4,5,6],index=pd.date_range('20130102',periods=6))

# %%
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df['F'] = s1

# %%
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.204171 -0.702792  0.585163 -0.347610  NaN
# 2013-01-02 -0.437881 -0.646395 -0.390188 -0.340307  1.0
# 2013-01-03 -0.329085 -1.030596 -1.394362  1.978588  2.0
# 2013-01-04 -0.032635 -0.559504  0.144842  1.153715  3.0
# 2013-01-05  0.463446  1.221839 -0.489961  0.009261  4.0
# 2013-01-06  2.094690  1.804389 -2.092649  0.297863  5.0

# %%
df.at[dates[0],'A'] = 0

# %%
df.iat[0,1] = 0

# %%
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.000000  0.000000  0.585163 -0.347610  NaN
# 2013-01-02 -0.437881 -0.646395 -0.390188 -0.340307  1.0
# 2013-01-03 -0.329085 -1.030596 -1.394362  1.978588  2.0
# 2013-01-04 -0.032635 -0.559504  0.144842  1.153715  3.0
# 2013-01-05  0.463446  1.221839 -0.489961  0.009261  4.0
# 2013-01-06  2.094690  1.804389 -2.092649  0.297863  5.0

# %%
df.loc[:,'D'] = np.array([5]* len(df))

# %%
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000  0.585163  5  NaN
# 2013-01-02 -0.437881 -0.646395 -0.390188  5  1.0
# 2013-01-03 -0.329085 -1.030596 -1.394362  5  2.0
# 2013-01-04 -0.032635 -0.559504  0.144842  5  3.0
# 2013-01-05  0.463446  1.221839 -0.489961  5  4.0
# 2013-01-06  2.094690  1.804389 -2.092649  5  5.0

# %%
df2 = df.copy()
df2
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000  0.585163  5  NaN
# 2013-01-02 -0.437881 -0.646395 -0.390188  5  1.0
# 2013-01-03 -0.329085 -1.030596 -1.394362  5  2.0
# 2013-01-04 -0.032635 -0.559504  0.144842  5  3.0
# 2013-01-05  0.463446  1.221839 -0.489961  5  4.0
# 2013-01-06  2.094690  1.804389 -2.092649  5  5.0

# %%
df2[df2 > 0] = -df2

# %%
df2
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -0.585163 -5  NaN
# 2013-01-02 -0.437881 -0.646395 -0.390188 -5 -1.0
# 2013-01-03 -0.329085 -1.030596 -1.394362 -5 -2.0
# 2013-01-04 -0.032635 -0.559504 -0.144842 -5 -3.0
# 2013-01-05 -0.463446 -1.221839 -0.489961 -5 -4.0
# 2013-01-06 -2.094690 -1.804389 -2.092649 -5 -5.0

# %%
df1 = df.reindex(index=dates[0:4],columns=list(df.columns) + ['E'])

# %%
df1.loc[dates[0]:dates[1],'E'] = 1

# %%
df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000  0.585163  5  NaN  1.0
# 2013-01-02 -0.437881 -0.646395 -0.390188  5  1.0  1.0
# 2013-01-03 -0.329085 -1.030596 -1.394362  5  2.0  NaN
# 2013-01-04 -0.032635 -0.559504  0.144842  5  3.0  NaN

# %%
df1.dropna(how='any')
# Out:
#                    A         B         C  D    F    E
# 2013-01-02 -0.437881 -0.646395 -0.390188  5  1.0  1.0

# %%
df1.fillna(value=666)
# Out:
#                    A         B         C  D      F      E
# 2013-01-01  0.000000  0.000000  0.585163  5  666.0    1.0
# 2013-01-02 -0.437881 -0.646395 -0.390188  5    1.0    1.0
# 2013-01-03 -0.329085 -1.030596 -1.394362  5    2.0  666.0
# 2013-01-04 -0.032635 -0.559504  0.144842  5    3.0  666.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %%
df.mean()
# Out:
# A    0.293089
# B    0.131622
# C   -0.606193
# D    5.000000
# F    3.000000
# dtype: float64

# %%
df.mean(1)
# Out:
# 2013-01-01    1.396291
# 2013-01-02    0.905107
# 2013-01-03    0.849191
# 2013-01-04    1.510541
# 2013-01-05    2.039065
# 2013-01-06    2.361286
# Freq: D, dtype: float64

# %%
s = pd.Series([1,3,5,np.nan,6,8],index=dates).shift(2)

# %%
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
sub = df.sub(s, axis='index')

# %%
print('{} first and {} second'.format(df.at[dates[3],'A'],sub.at[dates[3],'A']))
# Out:
# -0.032634883724014685 first and -3.0326348837240147 second

# %%
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000  0.585163  5  NaN
# 2013-01-02 -0.437881 -0.646395 -0.390188  5  1.0
# 2013-01-03 -0.329085 -1.030596 -1.394362  5  2.0
# 2013-01-04 -0.032635 -0.559504  0.144842  5  3.0
# 2013-01-05  0.463446  1.221839 -0.489961  5  4.0
# 2013-01-06  2.094690  1.804389 -2.092649  5  5.0

# %%
sub
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -1.329085 -2.030596 -2.394362  4.0  1.0
# 2013-01-04 -3.032635 -3.559504 -2.855158  2.0  0.0
# 2013-01-05 -4.536554 -3.778161 -5.489961  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D     F
# 2013-01-01  0.000000  0.000000  0.585163   5   NaN
# 2013-01-02 -0.437881 -0.646395  0.194975  10   1.0
# 2013-01-03 -0.766967 -1.676991 -1.199387  15   3.0
# 2013-01-04 -0.799602 -2.236495 -1.054545  20   6.0
# 2013-01-05 -0.336155 -1.014657 -1.544506  25  10.0
# 2013-01-06  1.758535  0.789733 -3.637155  30  15.0

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    2.532571
# B    2.834985
# C    2.677812
# D    0.000000
# F    4.000000
# dtype: float64

# %%
s = pd.Series(np.random.randint(0, 7, size=10))

# %%
s
# Out:
# 0    3
# 1    1
# 2    2
# 3    1
# 4    1
# 5    5
# 6    3
# 7    0
# 8    2
# 9    3
# dtype: int32

# %%
s.value_counts()
# Out:
# 3    3
# 1    3
# 2    2
# 5    1
# 0    1
# dtype: int64

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4))

# %%
df
# Out:
#           0         1         2         3
# 0 -0.873161  0.555847 -0.203184  0.539511
# 1  1.746330 -0.778072 -1.827059 -0.807045
# 2  1.527111 -1.118483  0.660619 -1.030423
# 3 -0.329690 -1.574755 -1.749903  0.776113
# 4  1.039099  0.438638 -1.571777  2.744267
# 5  0.221621 -0.715462  2.333333  0.012015
# 6  0.795787 -1.445487  0.451497  0.693735
# 7  0.273160 -0.188634  0.276823 -0.545091
# 8 -0.407570 -0.642362 -0.735030 -1.055802
# 9 -2.301470 -0.077635 -0.525501  2.856995

# %%
pieces = [df[:3],df[3:7],df[7:]]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.873161  0.555847 -0.203184  0.539511
# 1  1.746330 -0.778072 -1.827059 -0.807045
# 2  1.527111 -1.118483  0.660619 -1.030423
# 3 -0.329690 -1.574755 -1.749903  0.776113
# 4  1.039099  0.438638 -1.571777  2.744267
# 5  0.221621 -0.715462  2.333333  0.012015
# 6  0.795787 -1.445487  0.451497  0.693735
# 7  0.273160 -0.188634  0.276823 -0.545091
# 8 -0.407570 -0.642362 -0.735030 -1.055802
# 9 -2.301470 -0.077635 -0.525501  2.856995

# %%
pieces
# Out:
# [          0         1         2         3
#  0 -0.873161  0.555847 -0.203184  0.539511
#  1  1.746330 -0.778072 -1.827059 -0.807045
#  2  1.527111 -1.118483  0.660619 -1.030423,
#            0         1         2         3
#  3 -0.329690 -1.574755 -1.749903  0.776113
#  4  1.039099  0.438638 -1.571777  2.744267
#  5  0.221621 -0.715462  2.333333  0.012015
#  6  0.795787 -1.445487  0.451497  0.693735,
#           0         1         2         3
#  7  0.27316 -0.188634  0.276823 -0.545091
#  8 -0.40757 -0.642362 -0.735030 -1.055802
#  9 -2.30147 -0.077635 -0.525501  2.856995]

# %%
type(pieces[0])
# Out:
# pandas.core.frame.DataFrame

# %%
left = pd.DataFrame({'key': ['foo','foo'],'lval':[1,2]})

# %%
right = pd.DataFrame({'key': ['foo','foo'],'rval':[4,5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left,right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({'key': ['foo','bar'], 'lval':[1,2]})
right = pd.DataFrame({'key': ['foo','bar'], 'rval':[4,5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left,right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
df = pd.DataFrame(np.random.randn(8,4), columns=['A','B','C','D'])

# %%
df
# Out:
#           A         B         C         D
# 0  1.292176  1.328669 -0.590386 -0.354559
# 1  0.428767  0.769089  0.243083 -0.613862
# 2  0.435426 -1.136538 -0.364721 -0.892805
# 3 -0.114213 -0.253218  0.246333  0.573747
# 4 -0.854759  0.496746  0.741058 -0.469556
# 5  0.946104  0.701471 -0.534027  0.168106
# 6 -0.213674 -0.589900  0.394284  0.973794
# 7 -1.093868  0.452058  0.846133  0.103530

# %%
s = df.iloc[3]

# %%
df.append(s,ignore_index=True)
# Out:
#           A         B         C         D
# 0  1.292176  1.328669 -0.590386 -0.354559
# 1  0.428767  0.769089  0.243083 -0.613862
# 2  0.435426 -1.136538 -0.364721 -0.892805
# 3 -0.114213 -0.253218  0.246333  0.573747
# 4 -0.854759  0.496746  0.741058 -0.469556
# 5  0.946104  0.701471 -0.534027  0.168106
# 6 -0.213674 -0.589900  0.394284  0.973794
# 7 -1.093868  0.452058  0.846133  0.103530
# 8 -0.114213 -0.253218  0.246333  0.573747

# %%
df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar',
                        'foo', 'bar', 'foo', 'foo'],
                   'B': ['one', 'one', 'two', 'three',
                        'two', 'two', 'one', 'three'],
                   'C': np.random.randn(8),
                   'D': np.random.randn(8)})

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one  0.952641  0.323884
# 1  bar    one  1.357077  0.535247
# 2  foo    two  0.502489  0.418550
# 3  bar  three -0.504551  1.380767
# 4  foo    two  0.491802 -0.064147
# 5  bar    two -0.523049 -0.938237
# 6  foo    one -0.518410 -0.892633
# 7  foo  three -1.489222  1.288266

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar  0.329478  0.977777
# foo -0.060699  1.073921

# %%
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one    1.357077  0.535247
#     three -0.504551  1.380767
#     two   -0.523049 -0.938237
# foo one    0.434232 -0.568749
#     three -1.489222  1.288266
#     two    0.994291  0.354403

# %%
#plotting 
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
ts = ts.cumsum()

# %%
# %matplotlib notebook
ts.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
